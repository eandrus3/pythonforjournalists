# %% [markdown]
# # Final Project Update - Tidied Dataset Assignment

# %% [markdown]
# ## Dataset 1

# %% [markdown]
# - This dataset came from https://healthdata.gov/
# - Here is where you can download the raw dataset:
# https://healthdata.gov/dataset/Use-of-Telemedicine-During-COVID-19/c835-etjt
# - Here is where you can download the tidied dataset:
# https://docs.google.com/spreadsheets/d/1nLVdQnSvLo_WF9kW5ozSGuFCKxmIfQKSbzPAr1-AhT0/edit?usp=sharing
# - I tidied my dataset by eliminating the "Round," "Suppression" and "Significant" rows, because I didn't feel they added or contributed enough of what I needed for my story. I also organized the columns and rows better so the data was more readable.
# - Originally, I asked the question, "What is the background of how they sampled people for this?" I don't think I'm going to get a super clear answer since it appears to be random.
# - This data supports the story I'm telling by showing the demographics of individual people who had or did not have telehealth access.

# %% [markdown]
# ### Raw Dataset

# %%
dfRaw1 = pd.read_csv("Use_of_Telemedicine_During_COVID-19.csv")

# %%
dfRaw1.head(10)
# Out:
#    Round                     Indicator      Group     Subgroup  Sample Size  \
# 0      1  Provider offers telemedicine      Total        Total       6786.0
# 1      1  Provider offers telemedicine      Total        Total          NaN
# 2      1  Provider offers telemedicine      Total        Total          NaN
# 3      1  Provider offers telemedicine      Total        Total          NaN
# 4      1  Provider offers telemedicine      Total        Total          NaN
# 5      1  Provider offers telemedicine  Age group  18-44 years       2607.0
# 6      1  Provider offers telemedicine  Age group  18-44 years          NaN
# 7      1  Provider offers telemedicine  Age group  18-44 years          NaN
# 8      1  Provider offers telemedicine  Age group  18-44 years          NaN
# 9      1  Provider offers telemedicine  Age group  18-44 years          NaN
#
#                  Response  Percent  Standard Error Suppression  Significant
# ...

# %%
dfRaw1.tail(10)
# Out:
#      Round                                        Indicator  \
# 522      2  Provider offered telemedicine prior to pandemic
# 523      2  Provider offered telemedicine prior to pandemic
# 524      2  Provider offered telemedicine prior to pandemic
# 525      2  Provider offered telemedicine prior to pandemic
# 526      2  Provider offered telemedicine prior to pandemic
# 527      2  Provider offered telemedicine prior to pandemic
# 528      2  Provider offered telemedicine prior to pandemic
# 529      2  Provider offered telemedicine prior to pandemic
# 530      2  Provider offered telemedicine prior to pandemic
# 531      2  Provider offered telemedicine prior to pandemic
#
#                   Group                Subgroup  Sample Size  \
# 522  Chronic conditions  Diagnosed hypertension       2181.0
# 523  Chronic conditions  Diagnosed hypertension          NaN
# 524  Chronic conditions  Diagnosed hypertension          NaN
# ...

# %%
dfRaw1.shape
# Out:
# (532, 10)

# %% [markdown]
# ### Tidied Dataset

# %%
import pandas as pd

# %%
dfTidied1 = pd.read_csv("Use_of_Telemedicine_During_COVID-19 - Tidied - Dataset 1.csv")

# %%
dfTidied1.head(10)
# Out:
#    Unnamed: 0                     Indicator      Group     Subgroup  \
# 0         NaN  Provider offers telemedicine      Total        Total
# 1         NaN  Provider offers telemedicine      Total        Total
# 2         NaN  Provider offers telemedicine      Total        Total
# 3         NaN  Provider offers telemedicine      Total        Total
# 4         NaN  Provider offers telemedicine      Total        Total
# 5         NaN                           NaN        NaN          NaN
# 6         NaN  Provider offers telemedicine  Age group  18-44 years
# 7         NaN  Provider offers telemedicine  Age group  18-44 years
# 8         NaN  Provider offers telemedicine  Age group  18-44 years
# 9         NaN  Provider offers telemedicine  Age group  18-44 years
#
#    Sample Size                Response  Percent  Standard Error
# 0       6786.0                   Total    100.0             NaN
# 1          NaN                     Yes     36.6             0.8
# ...

# %%
dfTidied1.tail(10)
# Out:
#      Unnamed: 0                                        Indicator  \
# 276         NaN  Provider offered telemedicine prior to pandemic
# 277         NaN  Provider offered telemedicine prior to pandemic
# 278         NaN  Provider offered telemedicine prior to pandemic
# 279         NaN  Provider offered telemedicine prior to pandemic
# 280         NaN  Provider offered telemedicine prior to pandemic
# 281         NaN  Provider offered telemedicine prior to pandemic
# 282         NaN  Provider offered telemedicine prior to pandemic
# 283         NaN  Provider offered telemedicine prior to pandemic
# 284         NaN  Provider offered telemedicine prior to pandemic
# 285         NaN  Provider offered telemedicine prior to pandemic
#
#                   Group                Subgroup  Sample Size  \
# 276  Chronic conditions  Diagnosed hypertension       2419.0
# 277  Chronic conditions  Diagnosed hypertension          NaN
# 278  Chronic conditions  Diagnosed hypertension          NaN
# ...

# %%
dfTidied1.shape
# Out:
# (286, 8)

# %% [markdown]
# ## Dataset 2

# %% [markdown]
# - This dataset came from https://www.cdc.gov/
# - Here is where you can download the raw dataset:
# https://www.cdc.gov/mmwr/volumes/69/wr/pdfs/mm6950a4-H.pdf
# - Here is a link to the tidied dataset: https://docs.google.com/spreadsheets/d/1X9FVBh0FXyrGSyp_DulSDnjRryO6CyhnzHruxxpXYwg/edit?usp=sharing
# - I honestly did not feel the dataset needed to be tidied. It made clear sense and I didn't want to eliminate too much important information.
# - Originally, I asked the question, "What do these categories mean?" I found out what they mean by digging more into the information behind the data collection. It was a lot of technical language which I found difficult to deal with when I first started collecting it.
# - This data supports the story I'm telling by showing regional overviews of telehealth access.

# %%
import pandas as pd
dfRaw2 = pd.read_csv('Data1 - Sheet1.csv')

# %%
dfRaw2.head(10)
# Out:
#                                           Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0  Characteristics of health centers by percentag...         NaN         NaN
# 1                                                NaN         NaN         NaN
# 2                                                NaN         NaN         NaN
# 3                                                NaN         NaN         NaN
# 4                                                NaN         NaN         NaN
# 5                                     Characteristic         NaN         NaN
# 6                                              Total         NaN         NaN
# 7                                             Region         NaN         NaN
# 8                                          Northeast         NaN         NaN
# 9                                            Midwest         NaN         NaN
#
#        Unnamed: 3                 Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# ...

# %%
dfRaw2.tail(10)
# Out:
#                                       Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 17                                 Full capacity         NaN         NaN
# 18                                  95% capacity         NaN         NaN
# 19                                < 90% capacity         NaN         NaN
# 20    Weekly visits before the COVID-19 pandemic         NaN         NaN
# 21                                      Decrease         NaN         NaN
# 22                                     No change         NaN         NaN
# 23                                      Increase         NaN         NaN
# 24  Personal protective equipment (PPE) shortage         NaN         NaN
# 25                                           Yes         NaN         NaN
# 26                                            No         NaN         NaN
#
#     Unnamed: 3 Unnamed: 4  Unnamed: 5  Unnamed: 6        Unnamed: 7  \
# 17  368 (36.5)   31 (8.4)  204 (55.4)  133 (36.1)          Referent
# ...

# %%
dfRaw2.shape
# Out:
# (27, 10)

# %% [markdown]
# ### Tidied Dataset

# %%
import pandas as pd

# %%
dfTidied2 = pd.read_csv("Data1 - Tidied - Sheet1.csv")

# %%
dfTidied2.head(10)
# Out:
#   Characteristics of health centers by percentage of visits provided using telehealth and factors associated with telehealth expansion (N=1,009) - Health Center COVID-19 Survey, United States, July 11-17, 2020  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                     Characteristic
# 5                                              Total
# 6                                             Region
# 7                                          Northeast
# 8                                            Midwest
# 9                                              South
#
#    Unnamed: 1  Unnamed: 2      Unnamed: 3                 Unnamed: 4  \
# 0         NaN         NaN             NaN                        NaN
# 1         NaN         NaN             NaN  No. (%) of health centers
# ...

# %%
dfTidied2.tail(10)
# Out:
#    Characteristics of health centers by percentage of visits provided using telehealth and factors associated with telehealth expansion (N=1,009) - Health Center COVID-19 Survey, United States, July 11-17, 2020  \
# 16                                      Full capacity
# 17                                       95% capacity
# 18                                     < 90% capacity
# 19         Weekly visits before the COVID-19 pandemic
# 20                                           Decrease
# 21                                          No change
# 22                                           Increase
# 23       Personal protective equipment (PPE) shortage
# 24                                                Yes
# 25                                                 No
#
#     Unnamed: 1  Unnamed: 2  Unnamed: 3 Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 16         NaN         NaN  368 (36.5)   31 (8.4)  204 (55.4)  133 (36.1)
# ...

# %%
dfTidied2.shape
# Out:
# (26, 10)
